# %% [markdown]
# # ⚡ Run Streamlit Dashboard on Google Colab
#
# This notebook allows you to run the interactive **Tesla Stock Price Forecasting Dashboard** directly in Google Colab using `localtunnel` to create a public web URL.

# %%
# 1. Clone the repository and navigate inside it
# !git clone https://github.com/yatharth-20/tesla-stock-predictor.git
# %cd tesla-stock-predictor

# %%
# 2. Install the required dependencies
# !pip install tensorflow pandas numpy scikit-learn matplotlib seaborn plotly streamlit statsmodels -q

# %%
# 3. Get your Colab Virtual Machine's public IP address
# You will need this IP address as the 'tunnel password' when you click the localtunnel link below.
print("Your Tunnel Password (IP Address) is:")
# !wget -qO- ipv4.icanhazip.com

# %%
# 4. Launch the Streamlit dashboard and expose it via Localtunnel
# Click the url starting with 'https://xxxx.loca.lt' that appears in the logs below.
# !streamlit run tesla_app.py & npx localtunnel --port 8501
